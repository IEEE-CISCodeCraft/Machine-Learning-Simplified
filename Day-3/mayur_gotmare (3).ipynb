# %% [markdown]
# # **Distances**

# %% [markdown]
# ## **Euclidean Distance**
#
# <img src = "https://i.ibb.co/hX25sCM/euclidean-distance.png" alt = "Euclidean Distance Formula" width = 700/>

# %% [markdown]
# ### **Euclidean Distance in 3D Space**

# %%
# Numpy for linear algebra and mathematical functions
import numpy as np

# Import the test case functions from the file
from LRTestCases import *

# %%
# Function to caluclate euclidean distance
def euclidean_distance_3d(point_1, point_2):
    # Extract x, y and z value from each point
    x1, y1, z1 = point_a
    x2, y2, z2 = point_b

    # Now we apply the formula for euclidean distance
    distance = (((x2-x1)**2 + (y2-y1)**2 + (z2-z1)**2)**0.5) # Write the formula here

    # Return the distance
    return distance

# %%
# Initialize points for calculating distance
point_a = (1, 2, 3)
point_b = (4, 5, 6)

# %%
# Calculate the distance
distance = euclidean_distance_3d(point_a, point_b)

# Print the distance
print(distance)
# Out:
# 5.196152422706632

# %%
# Call the test case function and check for correctness of code
test_euclidean_distance_3d(euclidean_distance_3d, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ### **Euclidean Distance in 2D Space**

# %%
# Numpy for linear algebra and mathematical functions
import numpy as np

# Import the test case functions from the file
from LRTestCases import *

# %%
# Function to caluclate euclidean distance
def euclidean_distance_2d(point_1, point_2):
    # Extract x and y value from each point
    x1, y1 = point_a
    x2, y2 = point_b

    # Now we apply the formula for euclidean distance
    distance = ((x2-x1)**2 + (y2-y1)**2)**0.5# Write the formula here

    # Return the distance
    return distance

# %%
# Initialize points for calculating distance
point_a = (1, 2)
point_b = (3, 4)

# %%
# Calculate the distance
distance = euclidean_distance_2d(point_a, point_b)

# Print the distance
print(distance)
# Out:
# 2.8284271247461903

# %%
# Call the test case function and check for correctness of code
test_euclidean_distance_2d(euclidean_distance_2d, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ## **Manhattan Distance**
#
# <img src = "https://i.ibb.co/2sGPN8Q/manhattan-distance.png" alt = "Euclidean Distance Formula" width = 700/>

# %% [markdown]
# ### **Manhattan Distance in 3D Space**

# %%
# Function to caluclate manhattan distance
def manhattan_distance_3d(point_1, point_2):
    # Extract x, y and z value from each point
    x1, y1, z1 = point_a
    x2, y2, z2 = point_b

    # Now we apply the formula for manhattan distance
    distance = abs(x2 - x1) + abs(y2 - y1) + abs(z2 - z1)  # Write the formula here

    # Return the distance
    return distance

# %%
# Initialize points for calculating distance
point_a = (1, 2, 3)
point_b = (4, 5, 6)

# %%
# Calculate the distance
distance = manhattan_distance_3d(point_a, point_b)

# Print the distance
print(distance)
# Out:
# 9

# %%
# Call the test case function and check for correctness of code
test_manhattan_distance_3d(manhattan_distance_3d, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ### **Manhattan Distance in 2D Space**

# %%
# Function to caluclate manhattan distance
def manhattan_distance_2d(point_1, point_2):
    # Extract x and y value from each point
    x1, y1 = point_a
    x2, y2 = point_b

    # Now we apply the formula for manhattan distance
    distance = abs(x2-x1)+ abs(y2-y1)# Write the formula here

    # Return the distance
    return distance

# %%
# Initialize points for calculating distance
point_a = (1, 2)
point_b = (3, 4)

# %%
# Calculate the distance
distance = manhattan_distance_2d(point_a, point_b)

# Print the distance
print(distance)
# Out:
# 4

# %%
# Call the test case function and check for correctness of code
test_manhattan_distance_2d(manhattan_distance_2d, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ## **Cosine Similarity**
#
# <img src = "https://i.ibb.co/J5D5hFm/cosine-similarity.png" alt = "Euclidean Distance Formula" width = 700/>

# %%
# Numpy for linear algebra and mathematical functions
import numpy as np

# %%
# Function to calculate cosine similarity
def cosine_similarity(vector1, vector2):
    # Get the dot of vectors -> Numerator
    dot_product = np.dot(vector1, vector2)

    # Calculate magnitude for each vector
    magnitude1 = np.linalg.norm(vector1)
    magnitude2 = np.linalg.norm(vector2)

    # Get the product of magnitude -> Denominator
    magnitude_product = magnitude1 * magnitude2 # Write the formula here

    # Calculate the similarity
    similarity = dot_product / magnitude_product # Write the formula here

    # Return the similarity value
    return similarity

# %% [markdown]
# ### **Cosine Similarity in 3D Space**

# %%
# Initialize points for calculating similarity
point_a = np.array([1, 2, 3])
point_b = np.array([4, 5, 6])

# %%
# Calculate the similarity
similarity = cosine_similarity(point_a, point_b)

# Print the similarity
print(similarity)
# Out:
# 0.9746318461970762

# %%
# Call the test case function and check for correctness of code
test_cosine_similarity(cosine_similarity, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ### **Cosine Similarity in 2D Space**

# %%
# Initialize points for calculating similarity
point_a = np.array([1, 2])
point_b = np.array([3, 4])

# %%
# Calculate the similarity
similarity = cosine_similarity(point_a, point_b)

# Print the similarity
print(similarity)
# Out:
# 0.9838699100999074

# %%
# Call the test case function and check for correctness of code
test_cosine_similarity(cosine_similarity, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# # **KMeans Clustering**

# %% [markdown]
# ## **Data**

# %%
# Import pandas for tabular dataframe management
import pandas as pd

# Import pandas for tabular dataframe management
df = pd.read_csv("/content/melanoma_tumor_full_data.csv") # Write the code to load the data

# View the top 5 records of the dataset
df.head(5)
# Out:
#    mass_npea  size_npear  malign_ratio  damage_size  exposed_area  \
# 0    6930.90     2919.02       0.42116      51.8298  9.888294e+05
# 1   10376.20     2613.88       0.25191     127.3370  1.434676e+06
# 2   13093.80     4510.06       0.34444     155.4400  1.812195e+06
# 3    7545.21     2882.36       0.38201      85.1237  1.043918e+06
# 4    6851.09     2195.18       0.32041      72.8283  9.484467e+05
#
#    std_dev_malign  err_malign  malign_penalty  damage_ratio
# 0        109.4870     2758.76            72.0       39.3620
# 1        160.0930     4635.26            73.0       29.9963
# 2        173.0150     5273.87            32.0       28.1354
# 3        124.4140     3263.35            57.0       35.0200
# 4         97.1881     3688.57            40.0       36.3481

# %%
# View the shape of data
df.shape
# Out:
# (50550, 9)

# %%
# We will select 5000 row at random for faster computing
# Also we will reset the indexing of our data and drop the old index
df = df.sample(5000, random_state = 42).reset_index(drop = True)

# View the top 5 records of the dataset
df.head(5)
# Out:
#    mass_npea  size_npear  malign_ratio  damage_size  exposed_area  \
# 0   12305.20     3728.33       0.30298     115.5090  1.688344e+06
# 1    9635.91     3212.28       0.33336      96.7172  1.339903e+06
# 2   13529.80     3545.04       0.26201     127.5630  1.931195e+06
# 3   10441.60     3085.19       0.29547     132.6200  1.473958e+06
# 4    8533.04     1835.54       0.21510      74.2112  1.226892e+06
#
#    std_dev_malign  err_malign  malign_penalty  damage_ratio
# 0         166.662     4260.17            61.0       32.1640
# 1         139.426     3618.89            13.0       35.3240
# 2         170.866     4892.47            79.0       28.4891
# 3         168.294     4416.80            35.0       31.7554
# 4         109.810     4064.29           103.0       34.7205

# %%
# View the shape of data
df.shape
# Out:
# (5000, 9)

# %% [markdown]
# ## **Clustering - 3 Principal Components**

# %% [markdown]
# ### **Dimensionality Reduction - PCA**

# %%
# Import PCA for dimensionality reduction
from sklearn.decomposition import PCA

# Initialize PCA with 3 principal components
pca_3_components = PCA(n_components=3)

# %%
# Get the decomposed data with 3 components
df_3_components = pca_3_components.fit_transform(df)

# View the data
df_3_components
# Out:
# array([[ 4.58095444e+05,  2.85676829e+01, -2.55882461e+02],
#        [ 1.09642667e+05,  2.82914635e+02, -2.56740479e+02],
#        [ 7.00947977e+05, -7.30113605e+02, -1.04594068e+02],
#        ...,
#        [-1.00860299e+05,  2.76966672e+01,  2.48423939e+02],
#        [ 1.87685133e+05, -1.93933624e+02,  3.71728371e+02],
#        [ 1.45103611e+05, -3.06810068e+02,  2.69797712e+02]])

# %% [markdown]
# ### **Plotting Decomposed Data**

# %%
# Import plotly for interactive plots
import plotly.express as px
import plotly.graph_objects as go

# %%
# Build the plot
fig = px.scatter_3d(
    x = df_3_components[:, 0],
    y = df_3_components[:, 1],
    z = df_3_components[:, 2],
)

# Customizing the plot
fig.update_layout(
    title = "PCA - 3D Visualization",
    width = 700,
    height = 500,
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a40ed5a6-869b-4665-8151-cad103640ce6" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a40ed5a6-869b-4665-8151-cad103640ce6")) {                    Plotly.newPlot(                        "a40ed5a6-869b-4665-8151-cad103640ce6",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[458095.44436254364,109642.6665992119,700947.9773156669,243701.44380874367,-3374.8964729055065,-389113.0248250453,139987.02891379304,328547.73168812,-261997.3885203606,-172665.06041290937,-90474.83078961863,9504.932136072983,-213497.4332121121,124046.10144908905,290457.82794322475,516185.2796449381,-315752.0490765144,-127951.82885608831,-464070.6723292536,55648.57940781718,345607.34977986454,210593.34183930224,-182017.54254274172,-24085.625444310997,-219488.6024844167,-455589.34147213725,146311.95046572262,249374.71165257087,-335527.73342078156,-162284.84349075195,821594.8850015472,-227885.52814993644,-159122.7788574628,237470.75498609076,-593070.931305327,82790.21620050486,371673.3231597583,843511.5804480807,568383.0853726094,892812.3890860041,1101282.7645953794,-248410.69000253244,-528288.2732206171,-301100.1334372718,125120.90511887145,294222.5459315389,329144.1317372316,337210.3914167359,41578.83014022432,202826.14815842532,54424.547598143836,-396100.7425048592,-652236.6620810819,82324.69084374375,-181598.00784234007,-368846.13296158373,-187750.56464553863,-50973.52541613143,-382900.4872239712,152188.0220849034,-178195.27108539199,13003.
# ## **Clustering - 2 Principal Components**

# %% [markdown]
# ### **Dimensionality Reduction - PCA**

# %%
# Import PCA for dimensionality reduction
from sklearn.decomposition import PCA

# Initialize PCA with 2 principal components
pca_2_components = PCA(n_components=2)

# %%
# Get the decomposed data with 2 components
df_2_components = pca_2_components.fit_transform(df)

# View the data
df_2_components
# Out:
# array([[ 4.58095444e+05,  2.85676829e+01],
#        [ 1.09642667e+05,  2.82914635e+02],
#        [ 7.00947977e+05, -7.30113605e+02],
#        ...,
#        [-1.00860299e+05,  2.76966672e+01],
#        [ 1.87685133e+05, -1.93933624e+02],
#        [ 1.45103611e+05, -3.06810068e+02]])

# %% [markdown]
# ### **Plotting Decomposed Data**

# %%
# Import plotly for interactive plots
import plotly.express as px
import plotly.graph_objects as go

# %%
# Build the plot
fig = px.scatter(
    x = df_2_components[:, 0],
    y = df_2_components[:, 1],
)

# Customizing the plot
fig.update_layout(
    title = "PCA - 2D Visualization",
    width = 700,
    height = 500,
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9049479c-90a9-4beb-938f-28f5e28db7b0" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9049479c-90a9-4beb-938f-28f5e28db7b0")) {                    Plotly.newPlot(                        "9049479c-90a9-4beb-938f-28f5e28db7b0",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[458095.4443625436,109642.66659921187,700947.9773156667,243701.44380874364,-3374.8964729055456,-389113.02482504526,139987.0289137931,328547.73168811994,-261997.38852036058,-172665.06041290937,-90474.83078961869,9504.932136072961,-213497.4332121121,124046.10144908904,290457.82794322475,516185.27964493807,-315752.0490765143,-127951.82885608824,-464070.6723292535,55648.579407817204,345607.3497798645,210593.34183930224,-182017.5425427417,-24085.62544431097,-219488.6024844167,-455589.34147213714,146311.9504657226,249374.71165257084,-335527.73342078156,-162284.84349075193,821594.885001547,-227885.52814993644,-159122.77885746275,237470.7549860907,-593070.9313053269,82790.21620050486,371673.32315975823,843511.5804480806,568383.0853726094,892812.3890860041,1101282.7645953791,-248410.6900025324,-528288.2732206171,-301100.1334372718,125120.90511887145,294222.54593153886,329144.13173723157,337210.39141673583,41578.830140224294,202826.1481584253,54424.5475981438,-396100.7425048591,-652236.6620810818,82324.69084374374,-181598.00784234004,-368846.1329615837,-187750.56464553863,-50973.52541613127,-382900.4872239712,152188.02208490335,-178195.27108539196,13003.44716652094,-524695.9390193345,-503156.75211832894,988259.3596426743,37563.44878288512,-442954.6014324069,-415875.9589949588,-649237.1832252238,-311800.51607094513,-166107.31806921592,568172.6902344666,191508.201690356,-318103.5384098965,-135211.86817769354,808290.5659125478,803747.750861213,-135633.93143587952,293833.21973368456,-327475.19374474237,853505.9159942017,-29612.181726650546,559843.2228542404,-615004.6156894177,-181031.2924052455,67452.01508192578,-415205.57842758606,-161217.3780716267,279920.0313443734,-120053.79125778773,-224161.58393035585,-485120.7453855272,741200.3281222096,760573.0445454482,639541.1184889291,-237510.12539361476,-585518.3859595901,81247.94257473416,-25019.203020162215,-572776.8855234982,-348385.7355887415,-125969.64853260272,-411056.9176051535,-114958.4089028719,-337267.36377227196,-694073.348609263,34894.193227842006,-152927.9082969715,-485862.5210540739,-298353.4425414382,1221030.7405609784,430580.5987540761,250002.68606755073,173007.36968388688,166012.75566216224,-275536.23091273487,347889.8602016694,-67101.94198325604,828166.5227165048,204661.27226070015,276889.34240377974,130497.92401472093,-375264.63912129996,-183966.66762104828,-338608.8110128534,-297630.95910105004,-83257.88611242171,296593.6687600526,-245533.42828390942,-93121.40192395913,388566.0664640187,-541904.8356501983,270920.0859062767,-88657.17208308469,375499.5831805002,-15965.490926449707,778121.1035251713,-329490.6178233548,-136246.75359871774,-87770.63150885225,-344987.4364285409,669225.7322584582,-530288.5392834008,-276918.4099588552,112786.89909100017,-124837.02590960613,843990.8498914198,136129.92384144902,-595998.0481869613,-172005.4810255211,15021.1173527758,1238652.3935145617,170568.88957414232,-146322.99190039941,-240686.51703318383,317697.83112382103,-136339.98803227345,-675007.7336644963,718741.4328109242,-185564.24307460833,-492636.6967504919,-397667.5655179055,90265.35634338036,-179117.25664268006,1045019.6308591905,-89083.73764311224,-53541.41704027278,227452.98648082805,35193.06934653305,-502776.7756327937,-313513.380565 ...

# %% [markdown]
# ### **Finding Optimal Clusters**

# %%
# Install `yellowbrick` for finding optimal cluster value
# !pip install yellowbrick --quiet

# Import KElbowVisualizer for ploting elbow method
from yellowbrick.cluster import KElbowVisualizer

# %%
# Import KMeans from scikit-learn
from sklearn.cluster import KMeans

# Initialize KMeans model
kmeans_model = KMeans(n_init = "auto")

# %%
# Initialize KElbowVisualizer with the model
visualizer = KElbowVisualizer(kmeans_model, k = (2, 10))

# Train the visualizer with the data
visualizer.fit(df_2_components)

# Plot the elbow plot
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### **Clustering**

# %%
# Initialize KMeans model with optimal clusters
kmeans_model = KMeans(n_clusters= 4 ,n_init="auto")

# Train the KMeans model and get the predicted cluster labels for the data
df_2_components_labels =  kmeans_model.fit_predict(df_2_components)

# %% [markdown]
# ### **Plotting Clustering Data**

# %%
# Initialize figure
fig = go.Figure()

# Add a trace for data points
fig.add_trace(
    go.Scatter(
        x = df_2_components[:, 0],
        y = df_2_components[:, 1],
        mode = "markers",
        marker_color = df_2_components_labels,
        marker = dict(
            showscale = True,
            size = 5
        ),
    )
)

# Add trace for cluster center
fig.add_trace(
    go.Scatter(
        x = kmeans_model.cluster_centers_[:, 0],
        y = kmeans_model.cluster_centers_[:, 1],
        mode = "markers",
        marker_color = "black",
        marker = dict(
            showscale = True,
            size = 20,
        ),
    )
)

# Update figure layout
fig.update_layout(
    title = "PCA 2D - Clusted Data",
    width = 700,
    height = 500,
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="63a9c3ba-1f73-45b3-b95f-a2ac185b9288" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63a9c3ba-1f73-45b3-b95f-a2ac185b9288")) {                    Plotly.newPlot(                        "63a9c3ba-1f73-45b3-b95f-a2ac185b9288",                        [{"marker":{"color":[2,2,0,2,1,3,2,2,1,1,1,1,1,2,2,0,3,1,3,1,2,2,1,1,1,3,2,2,3,1,0,1,1,2,3,2,2,0,0,0,0,1,3,3,2,2,2,2,1,2,1,3,3,2,1,3,1,1,3,2,1,1,3,3,0,1,3,3,3,3,1,0,2,3,1,0,0,1,2,3,0,1,0,3,1,1,3,1,2,1,1,3,0,0,0,1,3,2,1,3,3,1,3,1,3,3,1,1,3,3,0,2,2,2,2,1,2,1,0,2,2,2,3,1,3,3,1,2,1,1,2,3,2,1,2,1,0,3,1,1,3,0,3,1,2,1,0,2,3,