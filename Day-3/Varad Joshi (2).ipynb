# %% [markdown]
# # **Distances**

# %% [markdown]
# ## **Euclidean Distance**
#
# <img src = "https://i.ibb.co/hX25sCM/euclidean-distance.png" alt = "Euclidean Distance Formula" width = 700/>

# %% [markdown]
# ### **Euclidean Distance in 3D Space**

# %%
# Numpy for linear algebra and mathematical functions
import numpy as np

# Import the test case functions from the file
from LRTestCases import *
import math

# %%
# Function to caluclate euclidean distance
def euclidean_distance_3d(point_1, point_2):
    # Extract x, y and z value from each point
    x1, y1, z1 = point_a
    x2, y2, z2 = point_b

    squared_diff_x = (x2 - x1) ** 2
    squared_diff_y = (y2 - y1) ** 2
    squared_diff_z = (z2 - z1) ** 2

    # Sum of squared differences
    sum_of_squared_diff = squared_diff_x + squared_diff_y + squared_diff_z

    # Calculate the Euclidean distance by taking the square root
    distance = math.sqrt(sum_of_squared_diff)



    # Return the distance
    return distance

# %%
# Initialize points for calculating distance
point_a = (1, 2, 3)
point_b = (4, 5, 6)

# %%
# Calculate the distance
distance = euclidean_distance_3d(point_a, point_b)

# Print the distance
print(distance)
# Out:
# 5.196152422706632

# %%
# Call the test case function and check for correctness of code
test_euclidean_distance_3d(euclidean_distance_3d, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ### **Euclidean Distance in 2D Space**

# %%
# Numpy for linear algebra and mathematical functions
import numpy as np

# Import the test case functions from the file
from LRTestCases import *

# %%
# Function to caluclate euclidean distance
def euclidean_distance_2d(point_1, point_2):
    # Extract x and y value from each point
    x1, y1 = point_a
    x2, y2 = point_b


    # Calculate the squared differences in each dimension
    squared_diff_x = (x2 - x1) ** 2
    squared_diff_y = (y2 - y1) ** 2

    # Sum of squared differences
    sum_of_squared_diff = squared_diff_x + squared_diff_y

    # Calculate the Euclidean distance by taking the square root
    distance = math.sqrt(sum_of_squared_diff)



    # Return the distance
    return distance

# %%
# Initialize points for calculating distance
point_a = (1, 2)
point_b = (3, 4)

# %%
# Calculate the distance
distance = euclidean_distance_2d(point_a, point_b)

# Print the distance
print(distance)
# Out:
# 2.8284271247461903

# %%
# Call the test case function and check for correctness of code
test_euclidean_distance_2d(euclidean_distance_2d, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ## **Manhattan Distance**
#
# <img src = "https://i.ibb.co/2sGPN8Q/manhattan-distance.png" alt = "Euclidean Distance Formula" width = 700/>

# %% [markdown]
# ### **Manhattan Distance in 3D Space**

# %%
# Function to caluclate manhattan distance
def manhattan_distance_3d(point_1, point_2):
    # Extract x, y and z value from each point
    x1, y1, z1 = point_a
    x2, y2, z2 = point_b


     # Calculate the absolute differences in each dimension
    abs_diff_x = abs(x2 - x1)
    abs_diff_y = abs(y2 - y1)
    abs_diff_z = abs(z2 - z1)

    # Calculate the Manhattan distance
    distance = abs_diff_x + abs_diff_y + abs_diff_z




    # Return the distance
    return distance

# %%
# Initialize points for calculating distance
point_a = (1, 2, 3)
point_b = (4, 5, 6)

# %%
# Calculate the distance
distance = manhattan_distance_3d(point_a, point_b)

# Print the distance
print(distance)
# Out:
# 9

# %%
# Call the test case function and check for correctness of code
test_manhattan_distance_3d(manhattan_distance_3d, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ### **Manhattan Distance in 2D Space**

# %%
# Function to caluclate manhattan distance
def manhattan_distance_2d(point_1, point_2):
    # Extract x and y value from each point
    x1, y1 = point_a
    x2, y2 = point_b

# Calculate the absolute differences in each dimension
    abs_diff_x = abs(x2 - x1)
    abs_diff_y = abs(y2 - y1)

    # Calculate the Manhattan distance
    distance = abs_diff_x + abs_diff_y



    # Return the distance
    return distance

# %%
# Initialize points for calculating distance
point_a = (1, 2)
point_b = (3, 4)

# %%
# Calculate the distance
distance = manhattan_distance_2d(point_a, point_b)

# Print the distance
print(distance)
# Out:
# 4

# %%
# Call the test case function and check for correctness of code
test_manhattan_distance_2d(manhattan_distance_2d, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ## **Cosine Similarity**
#
# <img src = "https://i.ibb.co/J5D5hFm/cosine-similarity.png" alt = "Euclidean Distance Formula" width = 700/>

# %%
# Numpy for linear algebra and mathematical functions
import numpy as np

# %%
# Function to calculate cosine similarity
def cosine_similarity(vector1, vector2):
    # Get the dot of vectors -> Numerator
    dot_product = np.dot(vector1, vector2)

    # Calculate magnitude for each vector
    magnitude1 = np.linalg.norm(vector1)
    magnitude2 = np.linalg.norm(vector2)

    # Get the product of magnitude -> Denominator
    magnitude_product = magnitude1*magnitude2
    # Calculate the similarity
    similarity = dot_product / magnitude_product

    # Return the similarity value
    return similarity

# %% [markdown]
# ### **Cosine Similarity in 3D Space**

# %%
# Initialize points for calculating similarity
point_a = np.array([1, 2, 3])
point_b = np.array([4, 5, 6])

# %%
# Calculate the similarity
similarity = cosine_similarity(point_a, point_b)

# Print the similarity
print(similarity)
# Out:
# 0.9746318461970762

# %%
# Call the test case function and check for correctness of code
test_cosine_similarity(cosine_similarity, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# ### **Cosine Similarity in 2D Space**

# %%
# Initialize points for calculating similarity
point_a = np.array([1, 2])
point_b = np.array([3, 4])

# %%
# Calculate the similarity
similarity = cosine_similarity(point_a, point_b)

# Print the similarity
print(similarity)
# Out:
# 0.9838699100999074

# %%
# Call the test case function and check for correctness of code
test_cosine_similarity(cosine_similarity, point_a, point_b)
# Out:
# Test passed!

# %% [markdown]
# # **KMeans Clustering**

# %% [markdown]
# ## **Data**

# %%
# # Import pandas for tabular dataframe management
# import pandas as pd

# # Import pandas for tabular dataframe management
# df = None # Write the code to load the data

# # View the top 5 records of the dataset
# df.head(5)

import pandas as pd

# Load data from Excel file
df = pd.read_csv('/content/melanoma_tumor_full_data.csv')

# View the top 5 records of the dataset
print(df.head(5))
# Out:
#    mass_npea  size_npear  malign_ratio  damage_size  exposed_area  \
# 0    6930.90     2919.02       0.42116      51.8298  9.888294e+05
# 1   10376.20     2613.88       0.25191     127.3370  1.434676e+06
# 2   13093.80     4510.06       0.34444     155.4400  1.812195e+06
# 3    7545.21     2882.36       0.38201      85.1237  1.043918e+06
# 4    6851.09     2195.18       0.32041      72.8283  9.484467e+05
#
#    std_dev_malign  err_malign  malign_penalty  damage_ratio
# 0        109.4870     2758.76              72       39.3620
# 1        160.0930     4635.26              73       29.9963
# 2        173.0150     5273.87              32       28.1354
# 3        124.4140     3263.35              57       35.0200
# 4         97.1881     3688.57              40       36.3481

# %%
# View the shape of data
df.shape
# Out:
# (14289, 9)

# %%
# We will select 5000 row at random for faster computing
# Also we will reset the indexing of our data and drop the old index
df = df.sample(5000, random_state = 42).reset_index(drop = True)

# View the top 5 records of the dataset
df.head(5)
# Out:
#    mass_npea  size_npear  malign_ratio  damage_size  exposed_area  \
# 0    6731.36     2148.87       0.31923      64.9643  9.127102e+05
# 1    4796.70     1654.93       0.34501      41.5760  6.721483e+05
# 2   10011.90     3311.63       0.33076      90.6979  1.361123e+06
# 3    8470.55     2159.40       0.25493      78.6646  1.171422e+06
# 4   14076.30     5070.17       0.36019      84.3040  1.919323e+06
#
#    std_dev_malign  err_malign  malign_penalty  damage_ratio
# 0        110.7970     2786.03              27       39.0676
# 1         64.4922     1908.66              42       43.9696
# 2        120.9580     3993.68              20       31.0022
# 3         97.6091     3982.48              56       36.0400
# 4        186.4020     4733.89             131       30.1117

# %%
# View the shape of data
df.shape
# Out:
# (5000, 9)

# %% [markdown]
# ## **Clustering - 3 Principal Components**

# %% [markdown]
# ### **Dimensionality Reduction - PCA**

# %%
from sklearn.decomposition import PCA

# Initialize PCA with 3 principal components
pca_3_components = PCA(n_components=3)

# %%
# # Get the decomposed data with 3 components
# df_3_components = None

# # View the data
# df_3_components


# Fit the PCA model and transform the data to 3 components
df_3_components = pca_3_components.fit_transform(df)

# Convert the transformed data into a DataFrame
df_3_components = pd.DataFrame(df_3_components, columns=['Component 1', 'Component 2', 'Component 3'])

# View the data
print(df_3_components)
# Out:
#         Component 1  Component 2  Component 3
# 0    -312763.723593   204.071594  -256.961173
# 1    -553334.978720   253.992862  -688.445082
# 2     135663.858015   338.870336    95.113297
# 3     -54045.079931  -400.400587   416.967156
# 4     693881.955219   835.919317  -221.650426
# ...             ...          ...          ...
# 4995 -508352.221003  -732.432657   -80.536581
# 4996 -610145.989854   442.761718 -1023.006471
# 4997  919256.485573 -1037.200454   188.376357
# 4998   -1514.204153  -509.817622   180.832876
# 4999   83406.424489   907.534794  -402.328894
#
# [5000 rows x 3 columns]

# %% [markdown]
# ### **Plotting Decomposed Data**

# %%
# Import plotly for interactive plots
import plotly.express as px
import plotly.graph_objects as go

# %%
import plotly.express as px

# Build the plot
fig = px.scatter_3d(
    x=df_3_components['Component 1'],
    y=df_3_components['Component 2'],
    z=df_3_components['Component 3'],
)

# Customizing the plot
fig.update_layout(
    title="PCA - 3D Visualization",
    width=700,
    height=500,
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="
...

# %% [markdown]
# ### **Finding Optimal Clusters**

# %%
# Install `yellowbrick` for finding optimal cluster value
# !pip install yellowbrick --quiet

# Import KElbowVisualizer for ploting elbow method
from yellowbrick.cluster import KElbowVisualizer

# %%
# Import KMeans from scikit-learn
from sklearn.cluster import KMeans

# Initialize KMeans model
kmeans_model = KMeans(n_init = "auto")

# %%
# Initialize KElbowVisualizer with the model
visualizer = KElbowVisualizer(kmeans_model, k = (2, 10))

# Train the visualizer with the data
visualizer.fit(df_3_components)

# Plot the elbow plot
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### **Clustering**

# %%
from sklearn.cluster import KMeans

# Initialize KMeans model with optimal clusters
num_clusters = 5  # Replace with the desired number of clusters
kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)

# Train the KMeans model and get the predicted cluster labels for the data
df_3_components_labels = kmeans_model.fit_predict(df_3_components)

# Print the predicted cluster labels
print(df_3_components_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# [0 3 4 ... 2 4 4]

# %% [markdown]
# ### **Plotting Clustered Data**

# %%
import plotly.graph_objects as go

# Initialize figure
fig = go.Figure()

# Add a trace for data points
fig.add_trace(
    go.Scatter3d(
        x=df_3_components['Component 1'],
        y=df_3_components['Component 2'],
        z=df_3_components['Component 3'],
        mode="markers",
        marker=dict(
            color=df_3_components_labels,
            size=5,
            colorscale="Viridis",  # Choose a suitable colorscale
            colorbar=dict(title="Cluster"),
        ),
    )
)

# Add trace for cluster center
fig.add_trace(
    go.Scatter3d(
        x=kmeans_model.cluster_centers_[:, 0],
        y=kmeans_model.cluster_centers_[:, 1],
        z=kmeans_model.cluster_centers_[:, 2],
        mode="markers",
        marker=dict(
            color="black",
            size=20,
        ),
    )
)

# Update figure layout
fig.update_layout(
    title="PCA 3D - Clustered Data",
    width=700,
    height=500,
    scene=dict(
        xaxis_title="Component 1",
        yaxis_title="Component 2",
        zaxis_title="Component 3",
    ),
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eee4b5b3-f7dd-494d-b7c2-59326760ba3e" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eee4b5b3-f7dd-494d-b7c2-59326760ba3e")) {                    Plotly.newPlot(                        "eee4b5b3-f7dd-494d-b7c2-59326760ba3e",                        [{"marker":{"color":[0,3,4,4,2,1,4,3,1,4,0,1,4,2,0,4,3,2,0,4,0,3,0,2,2,3,1,2,0,3,3,4,3,2,0,2,2,0,4,4,0,0,0,0,3,0,1,2,3,0,0,3,1,0,0,0,1,4,3,0,4,4,3,0,0,3,0,2,0,4,1,0,2,4,4,2,3,3,3,1,0,0,1,0,0,3,2,0,2,3,2,4,0,0,0,0,4,4,4,0,1,0,3,2,0,2,2,1,2,0,2,2,4,0,3,4,3,1,3,4,2,4,1,0,0,3,1,0,4,2,0,3,3,3,2,1,1,2,4,0,4,2,3,1,4,4,4,0,1,4,4,0,0,2,3,3,2,4,0,2,0,2,2,3,4,3,0,2,2,0,4,1,4,2,0,1,0,4,4,4,3,4,4,0,0,1,1,0,0,0,1,0,4,0,0,4,1,3,3,4,4,4,3,4,3,4,4,4,3,4,0,0,4,3,3,3,4,3,3,3,1,1,3,4,0,0,3,3,1,3,1,0,0,0,4,0,0,3,1,4,3,3,0,2,3,3,0,0,4,2,3,4,4,4,0,3,0,3,0,0,1,2,4,3,1,4,4,2,4,2,0,1,3,2,1,3,0,0,1,0,4,4,1,3,4,0,3,3,4,4,3,0,3,3,3,0,3,4,4,1,3,2,3,3,0,0,4,0,4,0,0,1,0,4,0,4,0,3,3,1,4,0,2,4,0,0,4,0,4,3,0,1,0,1,1,4,4,1,2,0,0,3,0,0,0,0,0,3,4,3,0,3,4,4,0,3,4,0,4,4,3,4,0,3,1,0,1,3,4,4,0,0,0,3,2,0,4,4,0,3,3,1,0,0,4,3,4,4,3,3,0,0,4,0,1,1,3,3,3,0,3,4,4,0,4,1,4,1,3,1,2,1,4,4,0,1,4,4,0,3,3,0,0,2,0,3,3,2,1,3,3,3,3,3,2,0,4,3,4,4,1,1,4,3,4,0,4,2,0,1,0,3,3,0,4,4,0,1,2,0,0,1,4,1,2,1,3,3,1,4,3,0,0,0,4,4,0,1,3,2,0,0,0,1,2,1,0,4,4,3,3,3,0,4,0,3,4,4,0,4,0,4,4,4,0,4,3,4,4,0,3,0,1,4,0,3,0,2,0,4,3,0,1,1,4,2,0,0,4,3,0,0,3,0,2,2
0,4,3,0,0,0,4,1,4,3,0,3,0,0,2,1,4,2,0,4,3,0,3,4,4,0,0,1,0,1,0,0,2,3,4,0,3,4,0,0,0,0,4,2,4,2,3,0,4,4,3,3,2,4,3,0,2,0,0,3,3,0,4,4,1,4,0,0,4,0,2,3,4,0,3,3,1,3,4,3,3,0,3,0,4,4,1,1,4,1,4,2,2,0,4,4,4,3,4,4,2,0,4,4,0,0,0,1,3,4,1,4,4,2,0,4,1,0,4,4,1,1,4,0,0,4,1,3,0,0,3,0,4,0,2,4,4,0,0,4,0,0,4,0,1,1,4,3,0,0,0,0,3,1,0,0,1,3,0,0,0,4,1,0,1,4,2,0,3,0,4,3,0,3,4,0,4,0,1,3,0,4,4,4,3,4,0,3,0,3,2,4,0,4,0,4,0,3,3,2,1,3,4,0,3,0,0,3,1,0,3,3,3,4,1,0,1,3,3,4,4,4,3,0,0,3,2,2,2,2,2,3,3,0,4,1,3,0,4,1,3,3,1,4,2,1,1,4,0,1,0,3,4,3,0,3,3,4,3,1,0,4,1,3,2,4,1,3,1,3,0,3,3,0,2,3,4,4,4,3,0,0,0,3,1,2,0,4,3,4,4,3,0,4,1,4,3,0,4,4,4,4,3,4,3,4,4,0,4,1,4,4,4,0,4,2,0,1,1,3,0,1,1,0,1,2,1,0,1,0,0,3,4,4,1,0,4,0,1,4,4,2,2,4,4,1,4,0,1,0,3,3,3,4,4,1,0,3,3,1,0,0,0,2,1,4,4,1,0,4,0,3,2 ...

# %% [markdown]
# ## **Clustering - 2 Principal Components**

# %% [markdown]
# ### **Dimensionality Reduction - PCA**

# %%
from sklearn.decomposition import PCA

# Initialize PCA with 2 principal components
pca_2_components = PCA(n_components=2)

# %%
# Fit the PCA model and transform the data to 2 components
df_2_components = pca_2_components.fit_transform(df)

# Convert the transformed data into a DataFrame
df_2_components = pd.DataFrame(df_2_components, columns=['Component 1', 'Component 2'])

# View the data
print(df_2_components)
# Out:
#         Component 1  Component 2
# 0    -312763.723593   204.071594
# 1    -553334.978720   253.992862
# 2     135663.858015   338.870336
# 3     -54045.079931  -400.400587
# 4     693881.955219   835.919317
# ...             ...          ...
# 4995 -508352.221003  -732.432657
# 4996 -610145.989854   442.761718
# 4997  919256.485573 -1037.200454
# 4998   -1514.204153  -509.817622
# 4999   83406.424489   907.534794
#
# [5000 rows x 2 columns]

# %% [markdown]
# ### **Plotting Decomposed Data**

# %%
# Import plotly for interactive plots
import plotly.express as px
import plotly.graph_objects as go

# %%
import plotly.express as px

# Build the plot
fig = px.scatter(
    x=df_2_components['Component 1'],
    y=df_2_components['Component 2'],
)

# Customizing the plot
fig.update_layout(
    title="PCA - 2D Visualization",
    width=700,
    height=500,
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="74ff0388-880c-4f41-bdb1-daeaccb7f43c" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74ff0388-880c-4f41-bdb1-daeaccb7f43c")) {                    Plotly.newPlot(                        "74ff0388-880c-4f41-bdb1-daeaccb7f43c",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[-312763.7235928815,-553334.9787195988,135663.85801538386,-54045.0799311696,693881.955218735,610108.2312040057,-20010.32436548892,-386241.7256395861,389443.63139364304,169270.08525942804,-310264.3159284895,248516.43111594798,185593.75131869316,959571.3646167561,-127770.22471488724,97434.2521186096,-403929.0316138057,1072613.5323164184,-131255.0294022651,9050.791921196571,-110934.92638166827,-374495.3991586142,-162148.83359280933,640513.8493004361,783581.8396115334,-369745.40769879904,474711.9597624674,853476.8560925145,-300852.3289712619,-502219.7480118591,-488460.75502454623,123775.49239447192,-360715.07697508653,699073.8952682227,-173686.115669748,840457.333092393,830698.6906098298,-295683.2039018315,183228.174042462,19204.654445867895